# %% [markdown]
# # Import Arcpy

# %%
import sys
sys.path.append('C:\\Program Files (x86)\\ArcGIS\\Desktop10.4\\bin')
sys.path.append('C:\\Program Files (x86)\\ArcGIS\\Desktop10.4\\arcpy')
sys.path.append('C:\\Program Files (x86)\\ArcGIS\\Desktop10.4\\ArcToolbox\\Scripts')
import arcpy

# %% [markdown]
# #Change projection from Washington South to UTM Zone 13N

# %%
shapefile = ("U:\\GEOG 458\\file\\saep_bg10.shp")
input_feature = r"U:\\GEOG 458\\file\\saep_bg10.shp"
out_feature = r"C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp"
out_coordinate = arcpy.SpatialReference('NAD 1983 UTM Zone 13N')
new_projection = arcpy.Project_management(input_feature, out_feature, out_coordinate)

# %%
fc = ("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp")

# %% [markdown]
# # Create a new field named "County" with data type of "text"

# %%
arcpy.AddField_management(fc, "County","text")
# Out:
# <Result 'C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp'>

# %% [markdown]
# # Print all the field name in the shapefile

# %%
fieldlist = arcpy.ListFields(fc)
for field in fieldlist:
    print field.name
# Out:
# FID
# Shape
# STATEFP10
# COUNTYFP10
# TRACTCE10
# BLKGRPCE10
# GEOID10
# NAMELSAD10
# MTFCC10
# FUNCSTAT10
# INTPTLON10
# INTPTLAT10
# ALANDM
# AWATERM
# ALANDMI
# AWATERMI
# Version
# POP2000
# POP2001
# POP2002
# POP2003
# POP2004
# POP2005
# POP2006
# POP2007
# POP2008
# POP2009
# POP2010
# POP2011
# POP2012
# POP2013
# POP2014
# POP2015
# POP2016
# CPOP00_10
# PCPOP00_10
# CPOP10_16
# PCPOP10_16
# HHP2000
# HHP2001
# HHP2002
# HHP2003
# HHP2004
# HHP2005
# HHP2006
# HHP2007
# HHP2008
# HHP2009
# HHP2010
# HHP2011
# HHP2012
# HHP2013
# HHP2014
# HHP2015
# HHP2016
# CHHP00_10
# PCHHP00_10
# CHHP10_16
# PCHHP10_16
# GQ2000
# GQ2001
# GQ2002
# GQ2003
# GQ2004
# GQ2005
# GQ2006
# GQ2007
# GQ2008
# GQ2009
# GQ2010
# GQ2011
# GQ2012
# GQ2013
# GQ2014
# GQ2015
# GQ2016
# CGQ00_10
# PCGQ00_10
# CGQ10_16
# PCGQ10_16
# HU2000
# HU2001
# HU2002
# HU2003
# HU2004
# HU2005
# HU2006
# HU2007
# HU2008
# HU2009
# HU2010
# HU2011
# HU2012
# HU2013
# HU2014
# HU2015
# HU2016
# CHU00_10
# ...

# %% [markdown]
# # Find out which field I need and print out

# %%
cursor = arcpy.da.SearchCursor(fc,"COUNTYFP10") 
for row in cursor:
    print row
del cursor
# Out:
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'001',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'003',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# (u'005',)
# ...

# %% [markdown]
# # Update "County' field based on "countyID"

# %%
cursor = arcpy.da.UpdateCursor(shapefile, ["COUNTYFP10","County"])
for row in cursor:
    if row[0] == u'001':  # If "COUNTYFP10" equals u'001', then County equals to Adams 
        row[1] = "Adams"
    elif row[0] == u'003':
        row[1] = "Asotin"
    elif row[0] == u'005':
        row[1] = "Benton"
    elif row[0] == u'007':
        row[1] = "Chealn"
    elif row[0] == u'009':
        row[1] = "Clallam"
    elif row[0] == u'011':
        row[1] = "Clark"
    elif row[0] == u'013':
        row [1] = "Columbia"
    elif row[0] == u'015':
        row[1] = "Cowlitz"
    elif row[0] == u'017':
        row [1] = "Douglas"
    elif row[0] == u'019':
        row[1] = "Ferry"
    elif row[0] == u'021':
        row[1] = "Franklin"
    elif row[0] == u'023':
        row[1] = "Garfield"
    elif row[0] == u'025':
        row[1] = "Grant"
    elif row[0] == u'027':
        row[1] = "Grays Harbor"
    elif row[0] == u'029':
        row[1] = "Island"
    elif row[0] == u'031':
        row[1] = "Jefferson"
    elif row[0] == u'033':
        row[1] = "King"
    elif row[0] == u'035':
        row[1] = "Kitsap"
    elif row[0] == u'037':
        row[1] = "Kittitas"
    elif row[0] == u'039':
        row[1] = "Klickitat"
    elif row[0] == u'041':
        row[1] = "Lewis"
    elif row[0] == u'043':
        row[1] = "Lincoln"
    elif row[0] == u'045':
        row[1] = "Mason"
    elif row[0] == u'047':
        row[1] = "Okanogan"
    elif row[0] == u'049':
        row[1] = "Pacific"
    elif row[0] == u'051':
        row[1] = "Pend Oreille"
    elif row[0] == u'053':
        row[1] = "Pierce"
    elif row[0] == u'055':
        row[1] = "San Juan"
    elif row[0] == u'057':
        row[1] = "Skagit"
    elif row[0] == u'059':
        row[1] = "Skamania"
    elif row[0] == u'061':
        row[1] = "Snohomish"
    elif row[0] == u'063':
        row[1] = "Spokane"
    elif row[0] == u'065':
        row[1] = "Stevens"
    elif row[0] == u'067':
        row[1] = "Thurston"
    elif row[0] == u'069':
        row[1] = " Wahkiaku"
    elif row[0] == u'071':
        row[1] = "Walla Walla"
    elif row[0] == u'073':
        row[1] = "Whatcom"
    elif row[0] == u'075':
        row[1] = "Whitman"
    elif row[0] == u'077':
        row[1] = "Yakima"
    cursor.updateRow(row)
    
    
del cursor

# %% [markdown]
# # Create two lists and one of them contains population in 2016 in each block, while another contains the ID of  each county. Also, I count how many blocks in each county for calculating the total population in each county.

# %%
my_list_POP = []
my_list_FP = []

cursor_POP = arcpy.da.SearchCursor(fc, ["POP2016", "COUNTYFP10"] ) # Append all the value from POP2016 to my_list
for row in cursor_POP:
    my_list_POP.append(row[0])
    my_list_FP.append(row[1])

# Count how many blocks in each county:

print "Count for 001:" + str(my_list_FP.count(u'001'))
print "Count for 003:" + str(my_list_FP.count(u'003'))
print "Count for 005:" + str(my_list_FP.count(u'005'))
print "Count for 007:" + str(my_list_FP.count(u'007'))
print "Count for 009:" + str(my_list_FP.count(u'009'))
print "Count for 011:" + str(my_list_FP.count(u'011'))
print "Count for 013:" + str(my_list_FP.count(u'013'))
print "Count for 015:" + str(my_list_FP.count(u'015'))
print "Count for 017:" + str(my_list_FP.count(u'017'))
print "Count for 019:" + str(my_list_FP.count(u'019'))
print "Count for 021:" + str(my_list_FP.count(u'021'))
print "Count for 023:" + str(my_list_FP.count(u'023'))
print "Count for 025:" + str(my_list_FP.count(u'025'))
print "Count for 027:" + str(my_list_FP.count(u'027'))
print "Count for 029:" + str(my_list_FP.count(u'029'))
print "Count for 031:" + str(my_list_FP.count(u'031'))
print "Count for 033:" + str(my_list_FP.count(u'033'))
print "Count for 035:" + str(my_list_FP.count(u'035'))
print "Count for 037:" + str(my_list_FP.count(u'037'))
print "Count for 039:" + str(my_list_FP.count(u'039'))
print "Count for 041:" + str(my_list_FP.count(u'041'))
print "Count for 043:" + str(my_list_FP.count(u'043'))
print "Count for 045:" + str(my_list_FP.count(u'045'))
print "Count for 047:" + str(my_list_FP.count(u'047'))
print "Count for 049:" + str(my_list_FP.count(u'049'))
print "Count for 051:" + str(my_list_FP.count(u'051'))
print "Count for 053:" + str(my_list_FP.count(u'053'))
print "Count for 055:" + str(my_list_FP.count(u'055'))
print "Count for 057:" + str(my_list_FP.count(u'057'))
print "Count for 059:" + str(my_list_FP.count(u'059'))
print "Count for 061:" + str(my_list_FP.count(u'061'))
print "Count for 063:" + str(my_list_FP.count(u'063'))
print "Count for 065:" + str(my_list_FP.count(u'065'))
print "Count for 067:" + str(my_list_FP.count(u'067'))
print "Count for 069:" + str(my_list_FP.count(u'069'))
print "Count for 071:" + str(my_list_FP.count(u'071'))
print "Count for 073:" + str(my_list_FP.count(u'073'))
print "Count for 075:" + str(my_list_FP.count(u'075'))
print "Count for 077:" + str(my_list_FP.count(u'077'))
# Out:
# Count for 001:15
# Count for 003:21
# Count for 005:137
# Count for 007:55
# Count for 009:55
# Count for 011:280
# Count for 013:5
# Count for 015:89
# Count for 017:29
# Count for 019:7
# Count for 021:49
# Count for 023:3
# Count for 025:46
# Count for 027:62
# Count for 029:57
# Count for 031:27
# Count for 033:1422
# Count for 035:164
# Count for 037:25
# Count for 039:19
# Count for 041:62
# Count for 043:11
# Count for 045:49
# Count for 047:44
# Count for 049:20
# Count for 051:14
# Count for 053:560
# Count for 055:14
# Count for 057:82
# Count for 059:10
# Count for 061:501
# Count for 063:322
# Count for 065:34
# Count for 067:161
# Count for 069:5
# Count for 071:43
# Count for 073:102
# Count for 075:33
# Count for 077:149

# %% [markdown]
# # Find out the population in each county by multiplying the number of block with population in each block

# %%
list_pop_county = []
list_pop_county.append(int(sum(my_list_POP[0:15])))
list_pop_county.append(int(sum(my_list_POP[15:36])))
list_pop_county.append(int(sum(my_list_POP[36:173])))
list_pop_county.append(int(sum(my_list_POP[173:228])))
list_pop_county.append(int(sum(my_list_POP[228:283])))
list_pop_county.append(int(sum(my_list_POP[283:563])))
list_pop_county.append(int(sum(my_list_POP[563:568])))
list_pop_county.append(int(sum(my_list_POP[568:657])))
list_pop_county.append(int(sum(my_list_POP[657:686])))
list_pop_county.append(int(sum(my_list_POP[686:693])))
list_pop_county.append(int(sum(my_list_POP[693:742])))
list_pop_county.append(int(sum(my_list_POP[742:745])))
list_pop_county.append(int(sum(my_list_POP[745:791])))
list_pop_county.append(int(sum(my_list_POP[791:853])))
list_pop_county.append(int(sum(my_list_POP[853:910])))
list_pop_county.append(int(sum(my_list_POP[910:937])))
list_pop_county.append(int(sum(my_list_POP[937:2359])))
list_pop_county.append(int(sum(my_list_POP[2359:2523])))
list_pop_county.append(int(sum(my_list_POP[2523:2548])))
list_pop_county.append(int(sum(my_list_POP[2548:2567])))
list_pop_county.append(int(sum(my_list_POP[2567:2629])))
list_pop_county.append(int(sum(my_list_POP[2629:2640])))
list_pop_county.append(int(sum(my_list_POP[2640:2689])))
list_pop_county.append(int(sum(my_list_POP[2689:2733])))
list_pop_county.append(int(sum(my_list_POP[2733:2753])))
list_pop_county.append(int(sum(my_list_POP[2753:2767])))
list_pop_county.append(int(sum(my_list_POP[2767:3327])))
list_pop_county.append(int(sum(my_list_POP[3327:3341])))
list_pop_county.append(int(sum(my_list_POP[3341:3423])))
list_pop_county.append(int(sum(my_list_POP[3423:3433])))
list_pop_county.append(int(sum(my_list_POP[3433:3934])))
list_pop_county.append(int(sum(my_list_POP[3934:4256])))
list_pop_county.append(int(sum(my_list_POP[4256:4290])))
list_pop_county.append(int(sum(my_list_POP[4290:4451])))
list_pop_county.append(int(sum(my_list_POP[4451:4456])))
list_pop_county.append(int(sum(my_list_POP[4456:4499])))
list_pop_county.append(int(sum(my_list_POP[4499:4601])))
list_pop_county.append(int(sum(my_list_POP[4601:4634])))
list_pop_county.append(int(sum(my_list_POP[4634:4783])))

print list_pop_county 
print len(list_pop_county) # Make sure I got the population data in all counties in WA
# Out:
# [19510, 22149, 190500, 75910, 73410, 461010, 4050, 104850, 40720, 7700, 88670, 2200, 94609, 72820, 82909, 31089, 2105099, 262589, 43710, 21270, 76890, 10640, 62320, 41730, 21180, 13290, 844489, 16320, 122269, 11500, 772860, 492530, 44100, 272690, 3999, 60729, 212540, 47939, 250899]
# 39

# %% [markdown]
# # Create a list that contains all the counties in WA with the same order as list_pop_county.

# %%
list_county = ["Adams", "Asotin", "Benton", "Chelan", "Clallam", "Clark", "Columbia", "Cowlitz", "Douglas", "Ferry"
              , "Franklin", "Garfield", "Grant", "Grays Harbor", "Island", "Jefferson", "King", "Kitsap", "Kittitas",
              "Klickitat", "Lewis", "Lincoln", "Mason", "Okanogan", "Pacific", "Pend Oreille", "Pierce", "San Juan", 
              "Skagit", "Skamania", "Snohomish", "Spokane", "Stevens", "Thurston", "Wahkiakum", "Walla Walla", 
              "Whatcom", "Whitman", "Yakima"]

print len(list_county) # Make sure I got all 39 counties in WA
# Out:
# 39

# %% [markdown]
# # Import numpy for sorting the county based on population

# %%
import numpy

county = numpy.array(list_county) # Built an array based on list_county
population = numpy.array(list_pop_county) # Built an array based on list_pop_county
sort = population.argsort() # Sort counties based on the number of population
sorted_based_POP = county[sort]
result = sorted_based_POP[:: -1] # Get the result with reversed order

print "Ten largest total populations in 2016 of counties in WA are:" + str(result[0:10])
# Out:
# Ten largest total populations in 2016 of counties in WA are:['King' 'Pierce' 'Snohomish' 'Spokane' 'Clark' 'Thurston' 'Kitsap' 'Yakima'
#  'Whatcom' 'Benton']

# %%
# Another way to do this is to create a list that sums up "list_county" and "list_pop_county". 
list_sum = [(list_pop_county), (list_county)] 
result  = sorted(zip(*list_sum), reverse = True) # Sorted the "list_sum"

print "Ten largest total populations in 2016 of counties with numbers in WA are: " + str(result[0:10])
# Out:
# Ten largest total populations in 2016 of counties with numbers in WA are: [(2105099, 'King'), (844489, 'Pierce'), (772860, 'Snohomish'), (492530, 'Spokane'), (461010, 'Clark'), (272690, 'Thurston'), (262589, 'Kitsap'), (250899, 'Yakima'), (212540, 'Whatcom'), (190500, 'Benton')]

# %% [markdown]
# # Print "County" out

# %%
cursor = arcpy.da.SearchCursor(fc, ["County"])
for row in cursor:
    print row
# Out:
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Adams',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Asotin',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# (u'Benton',)
# ...

# %% [markdown]
# # Make new layers for each county based on the field of "  County" in "saep_bg10.shp" and convert each county layer to shapefile.

# %%
arcpy.env.workspace = "C:\\Users\\sunz4\\Desktop\\Shapefile"
arcpy.env.overwriteOutput = True

Adams = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Adams.lyr", "County = 'Adams'")
arcpy.FeatureClassToFeatureClass_conversion ("Adams.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Adams.shp")
 
Asotin = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Asotin.lyr", "County = 'Asotin'")
arcpy.FeatureClassToFeatureClass_conversion ("Asotin.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Asotin.shp")

Benton = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Benton.lyr", "COUNTYFP10 = '005'")
arcpy.FeatureClassToFeatureClass_conversion ("Benton.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Benton.shp")

Chealn = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Chealn.lyr", "County = 'Chealn'")
arcpy.FeatureClassToFeatureClass_conversion ("Chealn.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Chealn.shp")

Clallam = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Clallam.lyr", "County = 'Clallam'")
arcpy.FeatureClassToFeatureClass_conversion ("Clallam.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Clallam.shp")

Clark = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Clark.lyr", "County = 'Clark'")
arcpy.FeatureClassToFeatureClass_conversion ("Clark.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Clark.shp")

Columbia = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Columbia.lyr", "County = 'Columbia'")
arcpy.FeatureClassToFeatureClass_conversion ("Columbia.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Columbia.shp")

Cowlitz = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Cowlitz.lyr", "County = 'Cowlitz'")
arcpy.FeatureClassToFeatureClass_conversion ("Cowlitz.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Cowlitz.shp")

Douglas = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Douglas.lyr", "County = 'Douglas'")
arcpy.FeatureClassToFeatureClass_conversion ("Douglas.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Douglas.shp")

Ferry = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Ferry.lyr", "County = 'Ferry'")
arcpy.FeatureClassToFeatureClass_conversion ("Ferry.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Ferry.shp")

Franklin = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Franklin.lyr", "County = 'Franklin'")
arcpy.FeatureClassToFeatureClass_conversion ("Franklin.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Franklin.shp")

Garfield = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Garfield.lyr", "County = 'Garfield'")
arcpy.FeatureClassToFeatureClass_conversion ("Garfield.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Garfield.shp")

Grant = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Grant.lyr", "County = 'Grant'")
arcpy.FeatureClassToFeatureClass_conversion ("Grant.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Grant.shp")

Grays_harbor = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Grays_Harbor.lyr", "County = 'Grays Harbor'")
arcpy.FeatureClassToFeatureClass_conversion ("Grays_Harbor.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Grays_Harbor.shp")

Island = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Island.lyr", "County = 'Island'")
arcpy.FeatureClassToFeatureClass_conversion ("Island.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Island.shp")

Jefferson = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Jefferson.lyr", "County = 'Jefferson'")
arcpy.FeatureClassToFeatureClass_conversion ("Jefferson.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Jefferson.shp")

King = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "King.lyr", "County = 'King'")
arcpy.FeatureClassToFeatureClass_conversion ("King.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "King.shp")

Kitsap = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Kitsap.lyr", "County = 'Kitsap'")
arcpy.FeatureClassToFeatureClass_conversion ("Kitsap.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Kitsap.shp")

Kittitas = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Kittitas.lyr", "County = 'Kittitas'")
arcpy.FeatureClassToFeatureClass_conversion ("Kittitas.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Kittitas.shp")

Klickitat = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Klickitat.lyr", "County = 'Klickitat'")
arcpy.FeatureClassToFeatureClass_conversion ("Klickitat.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Klickitat.shp")

Lewis = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Lewis.lyr", "County = 'Lewis'")
arcpy.FeatureClassToFeatureClass_conversion ("Lewis.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Lewis.shp")

Lincoln = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Lincoln.lyr", "County = 'Lincoln'")
arcpy.FeatureClassToFeatureClass_conversion ("Lincoln.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Lincoln.shp")

Mason = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Mason.lyr", "County = 'Mason'")
arcpy.FeatureClassToFeatureClass_conversion ("Mason.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Mason.shp")

Okanogan = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Okanogan.lyr", "County = 'Okanogan'")
arcpy.FeatureClassToFeatureClass_conversion ("Okanogan.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Okanogan.shp")

Pacific = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Pacific.lyr", "County = 'Pacific'")
arcpy.FeatureClassToFeatureClass_conversion ("Pacific.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Pacific.shp")

Pend_oreille = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Pend_oreille_2.lyr", "County = 'Pend Oreille'")
arcpy.FeatureClassToFeatureClass_conversion ("Pend_oreille_2.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Pend_oreille.shp")

Pierce = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Pierce.lyr", "County = 'Pierce'")
arcpy.FeatureClassToFeatureClass_conversion ("Pierce.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Pierce.shp")

Skagit = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Skagit.lyr", "County = 'Skagit'")
arcpy.FeatureClassToFeatureClass_conversion ("Skagit.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Skagit.shp")

Skamania = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Skamania.lyr", "County = 'Skamania'")
arcpy.FeatureClassToFeatureClass_conversion ("Skamania.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Skamania.shp")

Snohomish = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Snohomish.lyr", "County = 'Snohomish'")
arcpy.FeatureClassToFeatureClass_conversion ("Snohomish.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Snohomish.shp")

Spokane = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Spokane.lyr", "County = 'Spokane'")
arcpy.FeatureClassToFeatureClass_conversion ("Spokane.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Spokane.shp")

Stevens = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Stevens.lyr", "County = 'Stevens'")
arcpy.FeatureClassToFeatureClass_conversion ("Stevens.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Stevens.shp")

Thurston = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Thurston.lyr", "County = 'Thurston'")
arcpy.FeatureClassToFeatureClass_conversion ("Thurston.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Thurston.shp")

Wahkiaku = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Wahkiaku_1.lyr", "County = 'Wahkiaku'")
arcpy.FeatureClassToFeatureClass_conversion ("Wahkiaku_1.lyr", "C:\\Users\\sunz4\\Desktop\\File", "Wahkiaku_1.shp")

Whatcom = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Whatcom.lyr", "County = 'Whatcom'")
arcpy.FeatureClassToFeatureClass_conversion ("Whatcom.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Whatcom.shp")

Whitman = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Whitman.lyr", "County = 'Whitman'")
arcpy.FeatureClassToFeatureClass_conversion ("Whitman.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Whitman.shp")

Yakima = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Yakima.lyr", "County = 'Yakima'")
arcpy.FeatureClassToFeatureClass_conversion ("Yakima.lyr", "C:\\Users\\sunz4\\Desktop\\Shapefile", "Yakima.shp")

Walla_walla = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Walla_3.lyr", "County = 'Walla Walla'")
arcpy.FeatureClassToFeatureClass_conversion ("Walla_3.lyr", "C:\\Users\\sunz4\\Desktop\\Shapeile", "Walla_W.shp")

Wahkiaku = arcpy.MakeFeatureLayer_management("C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp", "Wahkiaku_2.lyr", "County = 'Wahkiaku'")
arcpy.FeatureClassToFeatureClass_conversion ("Wahkiaku_2.lyr", "C:\\Users\\sunz4\\Desktop\\File", "Wahkiaku_2.shp")
# Out:
# <Result 'C:\\Users\\sunz4\\Desktop\\file\\Wahkiaku_2.shp'>

# %%
from subprocess import call
import os
os.environ["GDAL_DATA"] = "C:\\OSGeo4W64\\share\\gdal"
os.environ["GDAL_DRIVER_PATH"] = "C:\\OSGeo4W64\\bin\\gdalplugins"
os.environ["PROJ_LIB"] = "C:\\OSGeo4W64\\share\\proj"
os.environ["PATH"] = "C:\\OSGeo4W64\\bin;"+os.environ["PATH"]+";C:\\OSGeo4W64\\apps\\msys\\bin;C:\\OSGeo4W64\\apps\\Python27\\Scripts"

os.chdir('C:\\Users\\sunz4\\Desktop\\file')
os.getcwd() # Set path
# Out:
# 'C:\\Users\\sunz4\\Desktop\\file'

# %% [markdown]
# I tried to use this loop to make geojson files but after couple tries, nothing show up in the end and it took 1 hour to run.

# %%
fe = "C:\\Users\\sunz4\\Desktop\\New Shp\\saep_10.shp" # Path of the shapefile
cursor = arcpy.SearchCursor(fe)
fieldname = "County"

for row in cursor:
    input_name = row.getValue(fieldname) # Get the value from the field of " County"
    output = "C:\\Users\\sunz4\\Desktop\\file" + input_name + ".geojson"
    
    call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      output,
      input_name])

# %% [markdown]
# So, I would just try to manually change the input and the output:(.

# %%
# Create GEOjson file from shapefile:

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Adams.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Adams.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Asotin.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Asotin.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Benton.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Benton.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Chealn.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Chealn.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Clallam.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Clallam.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Clark.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Clark.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Columbia.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Columbia.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Cowlitz.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Cowlitz.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Douglas.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Douglas.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Ferry.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Ferry.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Franklin.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Franklin.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Garfield.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Garfield.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Grant.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Grant.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Grays_Harbor.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Grays_Harbor.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Island.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Island.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Jefferson.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Jefferson.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\King.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\King.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Kitsap.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Kitsap.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Kittitas.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Kittitas.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Klickitat.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Klickitat.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Lewis.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Lewis.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Lincoln.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Lincoln.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Mason.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Mason.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Okanogan.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Okanogan.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Pacific.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Pacific.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Pend_oreille.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Pend_oreille.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Pierce.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Pierce.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Skagit.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Skagit.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Skamania.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Skamania.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Snohomish.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Snohomish.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Spokane.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Spokane.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Stevens.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Stevens.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Thurston.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Thurston.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Walla_walla.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Walla_W.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Whatcom.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Whatcom.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Whitman.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Whitman.shp'])

call(['C:\\OSGeo4W64\\bin\\ogr2ogr',
      '-f','GeoJSON','-t_srs','WGS84',
      '-s_srs','EPSG:26913',
      'C:\\Users\\sunz4\\Desktop\\file\\Yakima.geojson',
      'C:\\Users\\sunz4\\Desktop\\Shapefile\\Yakima.shp'])
# Out:
# 0

# %% [markdown]
# # This whole lab cost me about 5-6 hours in total to finish and I spent the most of the time typing. There is definitely one thing I need to improve, which is loop. I am not good at loop but it realy helps to me figure out how this Arcpy thing works in general without loop.
